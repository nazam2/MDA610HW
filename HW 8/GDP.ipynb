# %% [markdown]
# # GDP Data Analysis with Numpy
#
# -  We will analyze the [World Bank national GDP data](https://data.worldbank.org/indicator/NY.GDP.MKTP.CD) from 2012 to 2017.
# -  Data file `GDP.csv` is downloadable from the class repository.

# %%
# import pandas
import pandas as pd
# import Numpy
import numpy as np

# %% [markdown]
# ## Load the Data Set
#
# -  The code snippet below reads the data set and generates `gdp`, a Numpy ndarray.

# %%
# load the data set
df = pd.read_csv('GDP.csv')
# gdp is a numpy ndarray
gdp = df.loc[:, '2012':'2017'].values
df
# Out:
#               Country Name Country Code                      Region    2012  \
# 0              Afghanistan          AFG                  South Asia  0.0200
# 1                  Albania          ALB       Europe & Central Asia  0.0123
# 2                  Algeria          DZA  Middle East & North Africa  0.2091
# 3           American Samoa          ASM         East Asia & Pacific  0.0006
# 4                  Andorra          AND       Europe & Central Asia  0.0032
# ..                     ...          ...                         ...     ...
# 192  Virgin Islands (U.S.)          VIR   Latin America & Caribbean  0.0041
# 193     West Bank and Gaza          PSE  Middle East & North Africa  0.0113
# 194            Yemen, Rep.          YEM  Middle East & North Africa  0.0354
# 195                 Zambia          ZMB          Sub-Saharan Africa  0.0255
# 196               Zimbabwe          ZWE          Sub-Saharan Africa  0.0171
#
#        2013    2014    2015    2016    2017
# 0    0.0206  0.0205  0.0199  0.0194  0.0202
# 1    0.0128  0.0132  0.0114  0.0119  0.0130
# 2    0.2098  0.2138  0.1660  0.1601  0.1676
# 3    0.0006  0.0006  0.0007  0.0007  0.0006
# 4    0.0033  0.0034  0.0028  0.0029  0.0030
# ..      ...     ...     ...     ...     ...
# 192  0.0038  0.0036  0.0037  0.0039  0.0039
# 193  0.0125  0.0127  0.0127  0.0134  0.0145
# 194  0.0404  0.0432  0.0426  0.0310  0.0268
# 195  0.0280  0.0272  0.0212  0.0210  0.0259
# 196  0.0191  0.0195  0.0200  0.0205  0.0228
#
# [197 rows x 9 columns]

# %% [markdown]
# ## Explore Data
#
# -  In this section and the next, explore and manipulate the data in the Numpy array `gdp`.
# -  The array contains the national GDP data (in trillion US Dollars) from 2012 through 2017. The countries are organized by rows. Each column includes the national GDP data in a year.
# -  Write a Python code snippet with Numpy to answer each question. Do **not** use any explicit loop.

# %% [markdown]
# ### Question 1. How many rows (countries) are there in array `gdp`?

# %%
pass

gdp.shape[0]
# Out:
# 197

# %% [markdown]
# ### Question 2. How many columns (years) are there in array `gdp`?

# %%
pass
gdp.shape[1]
# Out:
# 6

# %% [markdown]
# ### Question 3. What is the data type of array `gdp`?

# %%
pass
x = np.array(gdp)   
print(x.dtype)
# Out:
# float64

# %% [markdown]
# ### Question 4. Output the first five countries' GDPs from 2013 through 2016 (from the second column through the fifth column).

# %%
pass
gdp[:,:5]
# Out:
# array([[2.00000e-02, 2.06000e-02, 2.05000e-02, 1.99000e-02, 1.94000e-02],
#        [1.23000e-02, 1.28000e-02, 1.32000e-02, 1.14000e-02, 1.19000e-02],
#        [2.09100e-01, 2.09800e-01, 2.13800e-01, 1.66000e-01, 1.60100e-01],
#        [6.00000e-04, 6.00000e-04, 6.00000e-04, 7.00000e-04, 7.00000e-04],
#        [3.20000e-03, 3.30000e-03, 3.40000e-03, 2.80000e-03, 2.90000e-03],
#        [1.28100e-01, 1.36700e-01, 1.45700e-01, 1.16200e-01, 1.01100e-01],
#        [1.20000e-03, 1.20000e-03, 1.30000e-03, 1.40000e-03, 1.50000e-03],
#        [5.46000e-01, 5.52000e-01, 5.26300e-01, 5.94700e-01, 5.57500e-01],
#        [1.06000e-02, 1.11000e-02, 1.16000e-02, 1.06000e-02, 1.05000e-02],
#        [2.50000e-03, 2.60000e-03, 2.60000e-03, 2.70000e-03, 2.60000e-03],
#        [1.54620e+00, 1.57620e+00, 1.46750e+00, 1.35150e+00, 1.21000e+00],
#        [4.09400e-01, 4.30100e-01, 4.42000e-01, 3.81800e-01, 3.94100e-01],
#        [6.97000e-02, 7.42000e-02, 7.52000e-02, 5.31000e-02, 3.79000e-02],
#        [1.07000e-02, 1.06000e-02, 1.10000e-02, 1.18000e-02, 1.18000e-02],
#        [3.07000e-02, 3.25000e-02, 3.34000e-02, 3.11000e-02, 3.23000e-02],
#        [1.33400e-01, 1.50000e-01, 1.72900e-01, 1.95100e-01, 2.21400e-01],
#        [4.70000e-03, 4.60000e-03, 4.60000e-03, 4.60000e-03, 4.50000e-03],
#        [6.57000e-02, 7.55000e-02, 7.88000e-02, 5.65000e-02, 4.77000e-02],
#        [4.97900e-01, 5.20900e-01, 5.30800e-01, 4.55900e-01, 4.69700e-01],
#        [1.60000e-03, 1.60000e-03, 1.70000e-03, 1.80000e-03, 1.80000e-03],
#        [8.20000e-03, 9.20000e-03, 9.70000e-03, 8.30000e-03, 8.60000e-03],
#        [1.80000e-03, 1.80000e-03, 2.00000e-03, 2.10000e-03, 2.20000e-03],
#        [2.71000e-02, 3.07000e-02, 3.30000e-02, 3.30000e-02, 3.39000e-02],
#        [1.72000e-02, 1.82000e-02, 1.86000e-02, 1.62000e-02, 1.69000e-02],
#        [1.61000e-02, 1.49000e-02, 1.63000e-02, 1.44000e-02, 1.56000e-02],
#        [2.46520e+00, 2.47280e+00, 2.45600e+00, 1.80220e+00, 1.79630e+00],
#        [1.90000e-02, 1.81000e-02, 1.71000e-02, 1.29000e-02, 1.14000e-02],
#        [5.39000e-02, 5.56000e-02, 5.68000e-02, 5.02000e-02, 5.32000e-02],
#        [1.12000e-02, 1.19000e-02, 1.24000e-02, 1.04000e-02, 1.09000e-02],
#        [2.30000e-03, 2.50000e-03, 2.70000e-03, 3.10000e-03, 3.00000e-03],
#        [1.80000e-03, 1.90000e-03, 1.90000e-03, 1.60000e-03, 1.70000e-03],
#        [1.41000e-02, 1.52000e-02, 1.67000e-02, 1.80000e-02, 2.00000e-02],
#        [2.91000e-02, 3.23000e-02, 3.49000e-02, 3.09000e-02, 3.26000e-02],
#        [1.82400e+00, 1.84200e+00, 1.80150e+00, 1.55290e+00, 1.52670e+00],
#        [2.50000e-03, 1.70000e-03, 1.90000e-03, 1.70000e-03, 1.80000e-03],
#        [1.24000e-02, 1.29000e-02, 1.39000e-02, 1.09000e-02, 1.01000e-02],
#        [2.67100e-01, 2.78400e-01, 2.60500e-01, 2.43900e-01, 2.50300e-01],
#        [8.53220e+00, 9.57040e+00, 1.04385e+01, 1.10155e+01, 1.11379e+01],
#        [3.70600e-01, 3.81900e-01, 3.81100e-01, 2.93500e-01, 2.82800e-01],
#        [1.00000e-03, 1.10000e-03, 1.10000e-03, 1.00000e-03, 1.00000e-03],
#        [2.93000e-02, 3.27000e-02, 3.59000e-02, 3.79000e-02, 3.71000e-02],
#        [1.37000e-02, 1.41000e-02, 1.42000e-02, 8.60000e-03, 9.00000e-03],
#        [4.65000e-02, 4.97000e-02, 5.06000e-02, 5.48000e-02, 5.72000e-02],
#        [2.68000e-02, 3.13000e-02, 3.53000e-02, 3.31000e-02, 3.53000e-02],
#        [5.65000e-02, 5.82000e-02, 5.77000e-02, 4.95000e-02, 5.16000e-02],
#        [7.31000e-02, 7.71000e-02, 8.07000e-02, 8.71000e-02, 9.14000e-02],
#        [3.10000e-03, 3.10000e-03, 3.20000e-03, 3.20000e-03, 3.10000e-03],
#        [2.50000e-02, 2.41000e-02, 2.34000e-02, 1.97000e-02, 2.05000e-02],
#        [2.07400e-01, 2.09400e-01, 2.07800e-01, 1.86800e-01, 1.95100e-01],
#        [3.27100e-01, 3.43600e-01, 3.53000e-01, 3.02700e-01, 3.12000e-01],
#        [1.40000e-03, 1.30000e-03, 1.50000e-03, 1.60000e-03, 1.80000e-03],
#        [5.00000e-04, 5.00000e-04, 5.00000e-04, 5.00000e-04, 6.00000e-04],
#        [6.07000e-02, 6.27000e-02, 6.61000e-02, 6.88000e-02, 7.23000e-02],
#        [8.79000e-02, 9.51000e-02, 1.01700e-01, 9.93000e-02, 9.99000e-02],
#        [2.79400e-01, 2.88600e-01, 3.05500e-01, 3.32700e-01, 3.32900e-01],
#        [2.14000e-02, 2.20000e-02, 2.26000e-02, 2.34000e-02, 2.42000e-02],
#        [2.24000e-02, 2.19000e-02, 2.17000e-02, 1.32000e-02, 1.12000e-02],
#        [2.30000e-02, 2.51000e-02, 2.66000e-02, 2.29000e-02, 2.40000e-02],
#        [4.80000e-03, 4.60000e-03, 4.40000e-03, 4.00000e-03, 3.80000e-03],
#        [4.33000e-02, 4.76000e-02, 5.56000e-02, 6.45000e-02, 7.43000e-02],
#        [4.00000e-03, 4.20000e-03, 4.90000e-03, 4.70000e-03, 4.90000e-03],
#        [2.56700e-01, 2.70000e-01, 2.72600e-01, 2.32900e-01, 2.39000e-01],
#        [2.68380e+00, 2.81110e+00, 2.85220e+00, 2.43820e+00, 2.47130e+00],
#        [1.72000e-02, 1.76000e-02, 1.82000e-02, 1.44000e-02, 1.40000e-02],
#        [9.00000e-04, 1.40000e-03, 1.30000e-03, 1.40000e-03, 1.40000e-03],
#        [1.58000e-02, 1.61000e-02, 1.65000e-02, 1.40000e-02, 1.44000e-02],
#        [3.54400e+00, 3.75250e+00, 3.89870e+00, 3.38140e+00, 3.49520e+00],
#        [4.19000e-02, 6.33000e-02, 5.36000e-02, 4.92000e-02, 5.50000e-02],
#        [2.45700e-01, 2.39900e-01, 2.37000e-01, 1.96600e-01, 1.95200e-01],
#        [8.00000e-04, 8.00000e-04, 9.00000e-04, 1.00000e-03, 1.10000e-03],
#        [5.20000e-03, 5.30000e-03, 5.50000e-03, 5.70000e-03, 5.80000e-03],
#        [5.04000e-02, 5.39000e-02, 5.87000e-02, 6.38000e-02, 6.87000e-02],
#        [7.60000e-03, 8.40000e-03, 8.80000e-03, 8.80000e-03, 8.60000e-03],
#        [1.00000e-03, 1.00000e-03, 1.10000e-03, 1.00000e-03, 1.20000e-03],
#        [2.90000e-03, 3.00000e-03, 3.10000e-03, 3.20000e-03, 3.50000e-03],
#        [7.90000e-03, 8.50000e-03, 8.80000e-03, 8.70000e-03, 8.00000e-03],
#        [1.84000e-02, 1.84000e-02, 1.96000e-02, 2.08000e-02, 2.16000e-02],
#        [2.62600e-01, 2.75700e-01, 2.91500e-01, 3.09400e-01, 3.20900e-01],
#        [1.27900e-01, 1.35200e-01, 1.40100e-01, 1.23100e-01, 1.26000e-01],
#        [1.47000e-02, 1.60000e-02, 1.78000e-02, 1.73000e-02, 2.07000e-02],
#        [1.82760e+00, 1.85670e+00, 2.03910e+00, 2.10360e+00, 2.29040e+00],
#        [9.17900e-01, 9.12500e-01, 8.90800e-01, 8.60900e-01, 9.31900e-01],
#        [5.98900e-01, 4.67400e-01, 4.34500e-01, 3.85900e-01, 4.19000e-01],
#        [2.18000e-01, 2.34600e-01, 2.34600e-01, 1.77500e-01, 1.70200e-01],
#        [2.25000e-01, 2.38500e-01, 2.58500e-01, 2.91500e-01, 3.00500e-01],
#        [2.57400e-01, 2.92900e-01, 3.10000e-01, 3.00500e-01, 3.19400e-01],
#        [2.07280e+00, 2.13050e+00, 2.15170e+00, 1.83230e+00, 1.86920e+00],
#        [1.48000e-02, 1.42000e-02, 1.39000e-02, 1.41000e-02, 1.41000e-02],
#        [6.20320e+00, 5.15570e+00, 4.85040e+00, 4.38950e+00, 4.92670e+00],
#        [3.10000e-02, 3.37000e-02, 3.61000e-02, 3.80000e-02, 3.93000e-02],
#        [2.08000e-01, 2.36600e-01, 2.21400e-01, 1.84400e-01, 1.37300e-01],
#        [5.04000e-02, 5.51000e-02, 6.14000e-02, 6.40000e-02, 6.92000e-02],
#        [2.00000e-04, 2.00000e-04, 2.00000e-04, 2.00000e-04, 2.00000e-04],
#        [1.22280e+00, 1.30560e+00, 1.41130e+00, 1.38280e+00, 1.41480e+00],
#        [6.50000e-03, 7.10000e-03, 7.40000e-03, 6.40000e-03, 6.70000e-03],
#        [1.74100e-01, 1.74200e-01, 1.62600e-01, 1.14600e-01, 1.09400e-01],
#        [6.60000e-03, 7.30000e-03, 7.50000e-03, 6.70000e-03, 6.80000e-03],
#        [1.02000e-02, 1.19000e-02, 1.33000e-02, 1.44000e-02, 1.58000e-02],
#        [2.81000e-02, 3.03000e-02, 3.13000e-02, 2.70000e-02, 2.77000e-02],
#        [4.42000e-02, 4.69000e-02, 4.83000e-02, 5.00000e-02, 5.12000e-02],
#        [2.70000e-03, 2.50000e-03, 2.60000e-03, 2.50000e-03, 2.30000e-03],
#        [2.70000e-03, 3.10000e-03, 3.10000e-03, 3.20000e-03, 3.30000e-03],
#        [8.19000e-02, 6.55000e-02, 4.11000e-02, 2.78000e-02, 2.62000e-02],
#        [4.28000e-02, 4.64000e-02, 4.85000e-02, 4.15000e-02, 4.30000e-02],
#        [5.67000e-02, 6.17000e-02, 6.61000e-02, 5.72000e-02, 5.90000e-02],
#        [4.30000e-02, 5.16000e-02, 5.53000e-02, 4.54000e-02, 4.53000e-02],
#        [9.90000e-03, 1.06000e-02, 1.07000e-02, 9.70000e-03, 1.00000e-02],
#        [6.00000e-03, 5.50000e-03, 6.00000e-03, 6.40000e-03, 5.40000e-03],
#        [3.14400e-01, 3.23300e-01, 3.38100e-01, 2.96600e-01, 2.96800e-01],
#        [2.90000e-03, 3.30000e-03, 3.70000e-03, 4.10000e-03, 4.40000e-03],
#        [1.24000e-02, 1.32000e-02, 1.43000e-02, 1.31000e-02, 1.40000e-02],
#        [9.20000e-03, 1.02000e-02, 1.13000e-02, 1.07000e-02, 1.14000e-02],
#        [2.00000e-04, 2.00000e-04, 2.00000e-04, 2.00000e-04, 2.00000e-04],
#        [5.20000e-03, 5.60000e-03, 5.40000e-03, 4.80000e-03, 4.70000e-03],
#        [1.17000e-02, 1.21000e-02, 1.28000e-02, 1.17000e-02, 1.22000e-02],
#        [1.20110e+00, 1.27440e+00, 1.31460e+00, 1.17060e+00, 1.07780e+00],
#        [3.00000e-04, 3.00000e-04, 3.00000e-04, 3.00000e-04, 3.00000e-04],
#        [8.70000e-03, 9.50000e-03, 9.50000e-03, 7.70000e-03, 8.10000e-03],
#        [5.70000e-03, 6.60000e-03, 7.10000e-03, 6.30000e-03, 6.50000e-03],
#        [1.23000e-02, 1.26000e-02, 1.22000e-02, 1.17000e-02, 1.12000e-02],
#        [4.10000e-03, 4.50000e-03, 4.60000e-03, 4.10000e-03, 4.40000e-03],
#        [9.83000e-02, 1.06800e-01, 1.10100e-01, 1.01200e-01, 1.03300e-01],
#        [1.53000e-02, 1.60000e-02, 1.70000e-02, 1.48000e-02, 1.09000e-02],
#        [5.99000e-02, 6.03000e-02, 6.54000e-02, 5.97000e-02, 6.33000e-02],
#        [1.30000e-02, 1.27000e-02, 1.28000e-02, 1.17000e-02, 1.13000e-02],
#        [1.00000e-04, 1.00000e-04, 1.00000e-04, 1.00000e-04, 1.00000e-04],
#        [1.89000e-02, 1.93000e-02, 2.00000e-02, 2.14000e-02, 2.12000e-02],
#        [8.39000e-01, 8.76900e-01, 8.91000e-01, 7.65300e-01, 7.83500e-01],
#        [1.76200e-01, 1.90800e-01, 2.00800e-01, 1.77200e-01, 1.87900e-01],
#        [1.05000e-02, 1.10000e-02, 1.19000e-02, 1.28000e-02, 1.33000e-02],
#        [6.90000e-03, 7.70000e-03, 8.20000e-03, 7.20000e-03, 7.50000e-03],
#        [4.59400e-01, 5.15000e-01, 5.68500e-01, 4.94600e-01, 4.04600e-01],
#        [9.70000e-03, 1.08000e-02, 1.14000e-02, 1.01000e-02, 1.07000e-02],
#        [8.00000e-04, 8.00000e-04, 8.00000e-04, 9.00000e-04, 1.30000e-03],
#        [5.10200e-01, 5.23500e-01, 4.99300e-01, 3.86700e-01, 3.71300e-01],
#        [7.67000e-02, 7.88000e-02, 8.11000e-02, 6.89000e-02, 6.59000e-02],
#        [2.24400e-01, 2.31200e-01, 2.44400e-01, 2.70600e-01, 2.78700e-01],
#        [2.00000e-04, 2.00000e-04, 2.00000e-04, 3.00000e-04, 3.00000e-04],
#        [4.04000e-02, 4.56000e-02, 4.99000e-02, 5.41000e-02, 5.80000e-02],
#        [2.13000e-02, 2.13000e-02, 2.32000e-02, 2.17000e-02, 2.08000e-02],
#        [3.33000e-02, 3.86000e-02, 4.03000e-02, 3.62000e-02, 3.61000e-02],
#        [1.92600e-01, 2.01200e-01, 2.01000e-01, 1.89800e-01, 1.91900e-01],
#        [2.50100e-01, 2.71800e-01, 2.84600e-01, 2.92800e-01, 3.04900e-01],
#        [5.00400e-01, 5.24200e-01, 5.45400e-01, 4.77600e-01, 4.72000e-01],
#        [2.16400e-01, 2.26100e-01, 2.29600e-01, 1.99400e-01, 2.06300e-01],
#        [1.01600e-01, 1.02500e-01, 1.02400e-01, 1.03400e-01, 1.04300e-01],
#        [1.86800e-01, 1.98700e-01, 2.06200e-01, 1.61700e-01, 1.51700e-01],
#        [1.71200e-01, 1.90900e-01, 1.99600e-01, 1.77900e-01, 1.88500e-01],
#        [2.21030e+00, 2.29710e+00, 2.06000e+00, 1.36360e+00, 1.28270e+00],
#        [7.30000e-03, 7.60000e-03, 8.00000e-03, 8.30000e-03, 8.50000e-03],
#        [8.00000e-04, 8.00000e-04, 8.00000e-04, 8.00000e-04, 8.00000e-04],
#        [1.80000e-03, 1.90000e-03, 1.80000e-03, 1.50000e-03, 1.60000e-03],
#        [3.00000e-04, 3.00000e-04, 3.00000e-04, 3.00000e-04, 3.00000e-04],
#        [7.36000e-01, 7.46600e-01, 7.56400e-01, 6.54300e-01, 6.44900e-01],
#        [1.78000e-02, 1.90000e-02, 1.98000e-02, 1.78000e-02, 1.90000e-02],
#        [4.33000e-02, 4.84000e-02, 4.71000e-02, 3.96000e-02, 4.06000e-02],
#        [1.10000e-03, 1.30000e-03, 1.30000e-03, 1.40000e-03, 1.40000e-03],
#        [3.80000e-03, 4.90000e-03, 5.00000e-03, 4.20000e-03, 3.70000e-03],
#        [2.95100e-01, 3.07600e-01, 3.14900e-01, 3.08000e-01, 3.18100e-01],
#        [9.34000e-02, 9.85000e-02, 1.00900e-01, 8.78000e-02, 8.98000e-02],
#        [4.64000e-02, 4.81000e-02, 4.99000e-02, 4.31000e-02, 4.46000e-02],
#        [1.10000e-03, 1.10000e-03, 1.20000e-03, 1.20000e-03, 1.20000e-03],
#        [3.96300e-01, 3.66600e-01, 3.50600e-01, 3.17400e-01, 2.96300e-01],
#        [1.33600e+00, 1.36190e+00, 1.37690e+00, 1.19910e+00, 1.23750e+00],
#        [6.84000e-02, 7.43000e-02, 7.94000e-02, 8.06000e-02, 8.24000e-02],
#        [8.00000e-04, 8.00000e-04, 9.00000e-04, 9.00000e-04, 1.00000e-03],
#        [1.40000e-03, 1.50000e-03, 1.50000e-03, 1.60000e-03, 1.70000e-03],
#        [7.00000e-04, 7.00000e-04, 7.00000e-04, 8.00000e-04, 8.00000e-04],
#        [6.81000e-02, 7.21000e-02, 8.22000e-02, 9.67000e-02, 9.56000e-02],
#        [5.00000e-03, 5.10000e-03, 5.20000e-03, 4.80000e-03, 3.20000e-03],
#        [5.44500e-01, 5.79400e-01, 5.74400e-01, 4.98100e-01, 5.12200e-01],
#        [6.68000e-01, 6.88500e-01, 7.09200e-01, 6.79800e-01, 6.70200e-01],
#        [7.60000e-03, 8.40000e-03, 9.10000e-03, 7.90000e-03, 7.00000e-03],
#        [3.97000e-02, 4.57000e-02, 5.00000e-02, 4.74000e-02, 4.98000e-02],
#        [3.97600e-01, 4.20300e-01, 4.07300e-01, 4.01300e-01, 4.12400e-01],
#        [6.70000e-03, 5.60000e-03, 4.00000e-03, 3.10000e-03, 2.50000e-03],
#        [3.90000e-03, 4.30000e-03, 4.60000e-03, 4.20000e-03, 4.40000e-03],
#        [5.00000e-04, 5.00000e-04, 4.00000e-04, 4.00000e-04, 4.00000e-04],
#        [2.58000e-02, 2.71000e-02, 2.75000e-02, 2.51000e-02, 2.17000e-02],
#        [4.50000e-02, 4.63000e-02, 4.76000e-02, 4.32000e-02, 4.18000e-02],
#        [8.74000e-01, 9.50600e-01, 9.34200e-01, 8.59800e-01, 8.63700e-01],
#        [3.52000e-02, 3.92000e-02, 4.35000e-02, 3.58000e-02, 3.62000e-02],
#        [7.00000e-04, 7.00000e-04, 8.00000e-04, 9.00000e-04, 1.00000e-03],
#        [2.31000e-02, 2.46000e-02, 2.73000e-02, 2.71000e-02, 2.41000e-02],
#        [1.75800e-01, 1.83300e-01, 1.33500e-01, 9.10000e-02, 9.34000e-02],
#        [3.74600e-01, 3.90100e-01, 4.03100e-01, 3.58100e-01, 3.57000e-01],
#        [2.67660e+00, 2.75360e+00, 3.03470e+00, 2.89640e+00, 2.65920e+00],
#        [1.61970e+01, 1.67848e+01, 1.75217e+01, 1.82193e+01, 1.87072e+01],
#        [5.13000e-02, 5.75000e-02, 5.72000e-02, 5.33000e-02, 5.27000e-02],
#        [5.18000e-02, 5.77000e-02, 7.67000e-02, 8.18000e-02, 8.18000e-02],
#        [8.00000e-04, 8.00000e-04, 8.00000e-04, 7.00000e-04, 8.00000e-04],
#        [1.55800e-01, 1.71200e-01, 1.86200e-01, 1.93200e-01, 2.05300e-01],
#        [4.10000e-03, 3.80000e-03, 3.60000e-03, 3.70000e-03, 3.90000e-03],
#        [1.13000e-02, 1.25000e-02, 1.27000e-02, 1.27000e-02, 1.34000e-02],
#        [3.54000e-02, 4.04000e-02, 4.32000e-02, 4.26000e-02, 3.10000e-02],
#        [2.55000e-02, 2.80000e-02, 2.72000e-02, 2.12000e-02, 2.10000e-02],
#        [1.71000e-02, 1.91000e-02, 1.95000e-02, 2.00000e-02, 2.05000e-02]])

# %% [markdown]
# ### Question 5. Output the last ten countries' GDPs in 2017 (the last column).

# %%
pass
np.sum(gdp[:,-1], axis=0)
# Out:
# 79.66299999999998

# %% [markdown]
# ### Question 6. Was the eighth country's GDP in 2017 higher than 0.5 trillion US Dollars? (True or false?)

# %%
pass
gdp[8,5] > 0.5
# Out:
# False

# %% [markdown]
# ## Manipulate and Aggregate Data

# %% [markdown]
# ### Question 7. How many GDP values in the array are higher than 0.5 trillion US Dollars?
#
# *Hint: use `np.sum()` to count the number of True elements.*

# %%
pass

np.sum(gdp > 0.5)
# Out:
# 142

# %% [markdown]
# ### Question 8. How many countries had a GDP higher than 0.5 trillion US Dollars in 2017?

# %%
pass
np.sum(gdp[:,5] > 0.5)
# Out:
# 23

# %% [markdown]
# ### Question 9. Out of those countries that had a GDP higher than 0.5 trillion US Dollars in 2017, how many countries' GDP in 2016 was lower than 0.5 trillion US Dollars?

# %%
pass
np.sum(gdp[gdp[:,5] > 0.5, 4] < 0.5)
# Out:
# 1

# %% [markdown]
# ### Question 10. How many countries had a lower GDP in 2017 than in 2016?

# %%
pass
gdp[:,5] < gdp[:,4]
# Out:
# array([False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False, False,  True,
#         True, False, False, False, False, False,  True, False, False,
#         True, False, False, False, False,  True, False, False])

# %% [markdown]
# ### Question 11. Output the row index of the country with the highest GDP in 2015.
#
# *Hint: use `np.argmax()`.*

# %%
pass
np.argmax(gdp[:,3])
# Out:
# 187

# %% [markdown]
# ### Question 12. Output the first fifteen countries' respective average yearly GDP from 2012 through 2017.
#
# - Hint: use parameter `axis` in `np.mean()`.

# %%
pass
np.mean(gdp[:15], axis=1)
# Out:
# array([2.01000000e-02, 1.24333333e-02, 1.87733333e-01, 6.33333333e-04,
#        3.10000000e-03, 1.24983333e-01, 1.35000000e-03, 5.69866667e-01,
#        1.09833333e-02, 2.61666667e-03, 1.41370000e+00, 4.12366667e-01,
#        5.85000000e-02, 1.13500000e-02, 3.25666667e-02])

# %% [markdown]
# ### Question 13. What was the global GDP in 2016 and 2017, respectively?

# %%
pass
np.sum(gdp[:,-2], axis=0)
# Out:
# 74.9563

# %% [markdown]
# ### Question 14. What was the fifth highest national GDP in 2017?
#
# *Hint: use `np.sort()`.*

# %%
pass
np.sort(gdp[:,5])[-5]
# Out:
# 2.6526

# %% [markdown]
# ### Question 15. How many countries' GDP increased by at least 30% from 2012 to 2017?

# %%
pass
np.sum(gdp[:,5]> 1.3) * gdp[:,0]
# Out:
# array([2.800000e-01, 1.722000e-01, 2.927400e+00, 8.400000e-03,
#        4.480000e-02, 1.793400e+00, 1.680000e-02, 7.644000e+00,
#        1.484000e-01, 3.500000e-02, 2.164680e+01, 5.731600e+00,
#        9.758000e-01, 1.498000e-01, 4.298000e-01, 1.867600e+00,
#        6.580000e-02, 9.198000e-01, 6.970600e+00, 2.240000e-02,
#        1.148000e-01, 2.520000e-02, 3.794000e-01, 2.408000e-01,
#        2.254000e-01, 3.451280e+01, 2.660000e-01, 7.546000e-01,
#        1.568000e-01, 3.220000e-02, 2.520000e-02, 1.974000e-01,
#        4.074000e-01, 2.553600e+01, 3.500000e-02, 1.736000e-01,
#        3.739400e+00, 1.194508e+02, 5.188400e+00, 1.400000e-02,
#        4.102000e-01, 1.918000e-01, 6.510000e-01, 3.752000e-01,
#        7.910000e-01, 1.023400e+00, 4.340000e-02, 3.500000e-01,
#        2.903600e+00, 4.579400e+00, 1.960000e-02, 7.000000e-03,
#        8.498000e-01, 1.230600e+00, 3.911600e+00, 2.996000e-01,
#        3.136000e-01, 3.220000e-01, 6.720000e-02, 6.062000e-01,
#        5.600000e-02, 3.593800e+00, 3.757320e+01, 2.408000e-01,
#        1.260000e-02, 2.212000e-01, 4.961600e+01, 5.866000e-01,
#        3.439800e+00, 1.120000e-02, 7.280000e-02, 7.056000e-01,
#        1.064000e-01, 1.400000e-02, 4.060000e-02, 1.106000e-01,
#        2.576000e-01, 3.676400e+00, 1.790600e+00, 2.058000e-01,
#        2.558640e+01, 1.285060e+01, 8.384600e+00, 3.052000e+00,
#        3.150000e+00, 3.603600e+00, 2.901920e+01, 2.072000e-01,
#        8.684480e+01, 4.340000e-01, 2.912000e+00, 7.056000e-01,
#        2.800000e-03, 1.711920e+01, 9.100000e-02, 2.437400e+00,
#        9.240000e-02, 1.428000e-01, 3.934000e-01, 6.188000e-01,
#        3.780000e-02, 3.780000e-02, 1.146600e+00, 5.992000e-01,
#        7.938000e-01, 6.020000e-01, 1.386000e-01, 8.400000e-02,
#        4.401600e+00, 4.060000e-02, 1.736000e-01, 1.288000e-01,
#        2.800000e-03, 7.280000e-02, 1.638000e-01, 1.681540e+01,
#        4.200000e-03, 1.218000e-01, 7.980000e-02, 1.722000e-01,
#        5.740000e-02, 1.376200e+00, 2.142000e-01, 8.386000e-01,
#        1.820000e-01, 1.400000e-03, 2.646000e-01, 1.174600e+01,
#        2.466800e+00, 1.470000e-01, 9.660000e-02, 6.431600e+00,
#        1.358000e-01, 1.120000e-02, 7.142800e+00, 1.073800e+00,
#        3.141600e+00, 2.800000e-03, 5.656000e-01, 2.982000e-01,
#        4.662000e-01, 2.696400e+00, 3.501400e+00, 7.005600e+00,
#        3.029600e+00, 1.422400e+00, 2.615200e+00, 2.396800e+00,
#        3.094420e+01, 1.022000e-01, 1.120000e-02, 2.520000e-02,
#        4.200000e-03, 1.030400e+01, 2.492000e-01, 6.062000e-01,
#        1.540000e-02, 5.320000e-02, 4.131400e+00, 1.307600e+00,
#        6.496000e-01, 1.540000e-02, 5.548200e+00, 1.870400e+01,
#        9.576000e-01, 1.120000e-02, 1.960000e-02, 9.800000e-03,
#        9.534000e-01, 7.000000e-02, 7.623000e+00, 9.352000e+00,
#        1.064000e-01, 5.558000e-01, 5.566400e+00, 9.380000e-02,
#        5.460000e-02, 7.000000e-03, 3.612000e-01, 6.300000e-01,
#        1.223600e+01, 4.928000e-01, 9.800000e-03, 3.234000e-01,
#        2.461200e+00, 5.244400e+00, 3.747240e+01, 2.267580e+02,
#        7.182000e-01, 7.252000e-01, 1.120000e-02, 2.181200e+00,
#        5.740000e-02, 1.582000e-01, 4.956000e-01, 3.570000e-01,
#        2.394000e-01])
